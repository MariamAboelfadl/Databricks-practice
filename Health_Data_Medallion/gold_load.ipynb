# %%
# %sql
SHOW TABLES IN my_catalog.default

# %%
# %sql
select * from my_catalog.default.fact_health

# %%
# %sql
OPTIMIZE my_catalog.default.fact_health
ZORDER BY (year);

# %%
# Read table from Databricks
df = spark.table("my_catalog.default.dim_date")

# Write to BigQuery
df.write \
  .format("bigquery") \
  .option("writeMethod", "direct") \
  .option("table", "ready-de27.health_dataset.dim_date") \
  .mode("overwrite") \
  .save()

# %%
# %sql
CREATE OR REPLACE TABLE `ready-de27.health_dataset.test_export`
AS
SELECT 1 AS id, 'ok' AS status;

# %%
# %sql
USE CATALOG bigquery_catalog;

CREATE OR REPLACE TABLE health_dataset.dim_date AS
SELECT * FROM my_catalog.default.dim_date;

# %%
# Read table from your Databricks catalog
source_df = spark.table("my_catalog.default.dim_date")

# Write directly to BigQuery via the connected catalog
source_df.write.mode("overwrite").saveAsTable("bigquery_catalog.health_dataset.dim_date")
