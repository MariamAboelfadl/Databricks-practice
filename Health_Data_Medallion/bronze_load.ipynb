# %%
# %sql
create or replace table my_catalog.default.bronze_heatlh_tb 
TBLPROPERTIES ('delta.columnMapping.mode' = 'name')
select *,_metadata.file_name AS source_file ,_metadata.file_modification_time AS file_modification_time,current_timestamp() AS INGESTION_TIME
from read_files('/Volumes/my_catalog/default/health_data/global_health_data.csv',
format=>'csv',
sep =>',',
header =>'true',
inferSchema => 'true');
select * from my_catalog.default.bronze_heatlh_tb
